# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data
r_df = pd.read_csv(city_data_to_load)
c_df = pd.read_csv(ride_data_to_load)
# Combine the data into a single dataset
rc_df = pd.merge(r_df,c_df)
rc1_df = rc_df
rc_df.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %%
# Obtain the x and y coordinates for each of the three city types

xyu_df = rc1_df.loc[rc1_df['type'] == "Urban"]
xyu_df
xyr_df = rc1_df.loc[rc1_df['type'] == "Rural"]
xyr_df
xys_df = rc1_df.loc[rc1_df['type'] == "Suburban"]
# rc2 = rc1_df.groupby(by=["type","city"]).sum()
# rc3 = rc1_df.groupby(by=["type","city"]).count()
# rc4 = pd.concat([rc2, rc3], sort=False)
# rc4["Avg Fare"] = rc4.fare / rc4.driver_count
# rc4.rename({'driver_count':'ride_count','fare':'Fare Total'}, axis=1, inplace=True)
# rc4.drop(["ride_id","date"],axis=1,inplace=True)
# rc4.head()

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types

xyu_df = rc1_df.loc[rc1_df['type'] == "Urban"]
xyu_df
xyr_df = rc1_df.loc[rc1_df['type'] == "Rural"]
xyr_df
xys_df = rc1_df.loc[rc1_df['type'] == "Suburban"]
# xys_df.plot(kind='scatter',x='',y='num_pets',color='red')
# plt.show()
Y1 = (xyu_df.fare / xyu_df.driver_count).tolist()
# dfs = ['xyu_df','xyr_df','xys_df']

X1 = xyu_df["city"].unique().tolist()
X2 = xyr_df["city"].unique().tolist()
X3 = xys_df["city"].unique().tolist()


Y1
xyu_dict = {'city': X1}

# D1 = xyu_df["driver_count"]
# D2 = xyr_df["driver_count"]
# D3 = xys_df["driver_count"]
# d1
print(Y1)
# # Build the scatter plots for each city types
# S1 = xyu_df['driver_count']
# S2 = xyr_df['driver_count']
# S3 = xys_df['driver_count'].values
# rc2 = rc1_df.groupby(by=["type","city"]).sum()
# rc3 = rc1_df.groupby(by=["type","city"]).count()
# rc4 = pd.concat([rc2, rc3], sort=False)
# rc4["Avg Fare"] = rc4.fare / rc4.driver_count
# rc4.rename({'driver_count':'ride_count','fare':'Fare Total'}, axis=1, inplace=True)
# rc4.drop(["ride_id","date"],axis=1,inplace=True)
# rc4
# X1 = xyu_df['city']
# X2 = xyr_df['city']
# X3 = xys_df['city']

# Y1 = xyu_df['fare']
# Y2 = xyr_df['fare']
# Y3 = xys_df['fare']

# print(S3)
# x_axis = np.arange(0, 100, 1)
# ride_count = rc4.ride_count.values
# ride_count



# pltu = plt.scatter(X1,Y1, c='b', s="S1" ,marker='o', label='Urban')
# pltr = plt.scatter(X2, Y2, c='r',s="S2", marker='o', label='Rural')
# plts = plt.scatter(X3, Y3, c='g', s="S3", marker='o', label='Suburban')

# plt.show()
# Add titles (main and on axis)

 
# plt.show()


# Create a legend

# Incorporate a text label regarding circle size

# Save Figure
# Out:
# [0.36657894736842106, 0.3684210526315789, 0.4715789473684211, 0.27, 0.6052631578947368, 0.25105263157894736, 0.7642105263157895, 0.4355263157894737, 1.0728947368421053, 0.713421052631579, 1.0457894736842106, 1.1557894736842105, 0.39026315789473687, 0.20394736842105263, 1.1607894736842106, 0.7976315789473684, 0.3005263157894737, 0.6792105263157895, 0.21789473684210525, 1.1110526315789473, 0.4302631578947369, 0.1276315789473684, 1.1318421052631578, 0.28710526315789475, 0.5628947368421052, 0.4302631578947369, 0.14, 0.9936842105263157, 0.33254237288135596, 0.603050847457627, 0.5715254237288135, 0.45440677966101695, 0.07932203389830508, 0.42406779661016947, 0.39186440677966106, 0.3164406779661017, 0.29779661016949155, 0.08305084745762713, 0.5496610169491526, 0.34847457627118644, 0.6913559322033899, 0.7372881355932204, 0.7276271186440678, 0.32067796610169497, 0.457457627118644, 0.28525423728813554, 0.44796610169491524, 0.3184745762711864, 0.29084745762711867, 0.233728813559322, 0.534237288
# ...

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents

# Build Pie Charts

# Save Figure

# %%
# Show Figure
plt.show()
